# %%
#Import Library
# %matplotlib inline  
import serial
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
#Check Port
# !ls /dev/tty.usb*
# Out:
# /dev/tty.usbmodem1411

# %%
#Start A Serial
ser = serial.Serial(
    port = '/dev/tty.usbmodem1411',
    baudrate = 9600,
    parity = serial.PARITY_NONE,
    stopbits = serial.STOPBITS_ONE,
    bytesize = serial.EIGHTBITS,
    timeout = 1
)
print(ser.name)
# Out:
# /dev/tty.usbmodem1411

# %%
#Read A Byte
line = ser.readline().strip()
while len(line) == 0:
    line = ser.readline().strip()

# %%
#Plot New Data
#hl, = plt.plot([], [])

# %%
#Read And Plot Byte
x = []
y = []
plt.ion()
while len(line) != 0:
    curTime = float(line)
    print(curTime)
    line = ser.readline().strip()
    
    curVal = float(line)
    print(curVal)
    line = ser.readline().strip()
    
    x.append(curTime)
    y.append(curVal)
    
    # First line - Print line, Second line - Print points.
    # Comment out one of the two lines. Don't use together!!!
    #hl, = plt.plot(curTime, curVal, 'ro')
    plt.scatter(x, y)
    
    # Showing the plot
    plt.show()
    plt.pause(0.0001)
# t.sleep(2)
    
   # hl.set_xdata(np.append(hl.get_xdata(), curTime))
  #  hl.set_ydata(np.append(hl.get_ydata(), curVal))
# Out:
# 0.0
# 42.0
# 200.0
# 13.0
# 401.0
# 9.0
# 602.0
# 0.0
# 802.0
# 7.0
# 1004.0
# 1.0
# 1205.0
# 99.0
# 1405.0
# 53.0
# 1606.0
# 43.0
# 1808.0
# 250.0

# %%
#Close Serial
ser.close()
